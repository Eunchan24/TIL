# %% [markdown]
# # 고흐가 그린 붓꽃은 어떤 종류인지 살펴 보자.

# %% [markdown]
# ## 01 데이터 수집하기
#
#
# - 붓꽃 특성 이름
#   - 꽃받침 길이 : SepalLengthCm
#   - 꽃받침 너비 : SepalWidthCm
#   - 꽃잎 길이 : PetalLengthCm
#   - 꽃잎 너비 : PetalWidthCm
#   - 꽃 종류 : Species
#     - Iris 종류 : Iris-setosa, Iris-versicolor, Iris-virginica

# %% [markdown]
# ## 02 데이터 불러오기

# %% [markdown]
# ### [Step 1] 붓꽃 데이터를 불러와 출력하기
#
# id | SepalLengthCm | SepalWidthCm | PetalLengthCm | PetalWidthCm | Species
#
# ##### - CSV 파일을 읽기
#   1. 먼저 파이썬에 기본 내장된 csv 모듈을 import 함
#   2. csv 파일 OPEN (파일객체)
#   3. 파일객체를 csv.reader(파일객체) 에 넣기
#      - csv.reader() 함수 : Iterator 타입인 reader 객체를 리턴하므로 for 루프를 돌며 한 라인씩 가져올 수 있음

# %%
# Iris.csv 파일 업로드하기 
from google.colab import files

uploaded = files.upload()

# %%
# (실습) csv 파일 데이터 불러오기 위한 csv 모듈 선언
import csv

# (실습) Iris.csv 파일 열기
f= open('iris.csv', encoding='euc-kr')

# (실습) Iris.csv 파일속 데이터를 읽어서(csv.reader)data 객체에 저장하기 
data = csv.reader(f)


# 전체 데이터를 행별로 result 리스트에 추가 및 출력하기 
# (실습) 빈 리스트 result 만들기
result = []

# (실습) 전체 데이터를 행별로 result 리스트에 추가 및 출력하기 
for row in data :
    result.append(row)   # 행별로 데이터 추가하기
    print(row)           # 행별로 데이터 출력하기
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
# ['1', '5.1', '3.5', '1.4', '0.2', 'Iris-setosa']
# ['2', '4.9', '3.0', '1.4', '0.2', 'Iris-setosa']
# ['3', '4.7', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['4', '4.6', '3.1', '1.5', '0.2', 'Iris-setosa']
# ['5', '5.0', '3.6', '1.4', '0.2', 'Iris-setosa']
# ['6', '5.4', '3.9', '1.7', '0.4', 'Iris-setosa']
# ['7', '4.6', '3.4', '1.4', '0.3', 'Iris-setosa']
# ['8', '5.0', '3.4', '1.5', '0.2', 'Iris-setosa']
# ['9', '4.4', '2.9', '1.4', '0.2', 'Iris-setosa']
# ['10', '4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['11', '5.4', '3.7', '1.5', '0.2', 'Iris-setosa']
# ['12', '4.8', '3.4', '1.6', '0.2', 'Iris-setosa']
# ['13', '4.8', '3.0', '1.4', '0.1', 'Iris-setosa']
# ['14', '4.3', '3.0', '1.1', '0.1', 'Iris-setosa']
# ['15', '5.8', '4.0', '1.2', '0.2', 'Iris-setosa']
# ['16', '5.7', '4.4', '1.5', '0.4', 'Iris-setosa']
# ['17', '5.4', '3.9', '1.3', '0.4', 'Iris-setosa']
# ['18', '5.1', '3.5', '1.4', '0.3', 'Iris-setosa']
# ['19', '5.7', '3.8', '1.7', '0.3', 'Iris-setosa']
# ['20', '5.1', '3.8', '1.5', '0.3', 'Iris-setosa']
# ['21', '5.4', '3.4', '1.7', '0.2', 'Iris-setosa']
# ['22', '5.1', '3.7', '1.5', '0.4', 'Iris-setosa']
# ['23', '4.6', '3.6', '1.0', '0.2', 'Iris-setosa']
# ['24', '5.1', '3.3', '1.7', '0.5', 'Iris-setosa']
# ['25', '4.8', '3.4', '1.9', '0.2', 'Iris-setosa']
# ['26', '5.0', '3.0', '1.6', '0.2', 'Iris-setosa']
# ['27', '5.0', '3.4', '1.6', '0.4', 'Iris-setosa']
# ['28', '5.2', '3.5', '1.5', '0.2', 'Iris-setosa']
# ['29', '5.2', '3.4', '1.4', '0.2', 'Iris-setosa']
# ['30', '4.7', '3.2', '1.6', '0.2', 'Iris-setosa']
# ['31', '4.8', '3.1', '1.6', '0.2', 'Iris-setosa']
# ['32', '5.4', '3.4', '1.5', '0.4', 'Iris-setosa']
# ['33', '5.2', '4.1', '1.5', '0.1', 'Iris-setosa']
# ['34', '5.5', '4.2', '1.4', '0.2', 'Iris-setosa']
# ['35', '4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['36', '5.0', '3.2', '1.2', '0.2', 'Iris-setosa']
# ['37', '5.5', '3.5', '1.3', '0.2', 'Iris-setosa']
# ['38', '4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['39', '4.4', '3.0', '1.3', '0.2', 'Iris-setosa']
# ['40', '5.1', '3.4', '1.5', '0.2', 'Iris-setosa']
# ['41', '5.0', '3.5', '1.3', '0.3', 'Iris-setosa']
# ['42', '4.5', '2.3', '1.3', '0.3', 'Iris-setosa']
# ['43', '4.4', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['44', '5.0', '3.5', '1.6', '0.6', 'Iris-setosa']
# ['45', '5.1', '3.8', '1.9', '0.4', 'Iris-setosa']
# ['46', '4.8', '3.0', '1.4', '0.3', 'Iris-setosa']
# ['47', '5.1', '3.8', '1.6', '0.2', 'Iris-setosa']
# ['48', '4.6', '3.2', '1.4', '0.2', 'Iris-setosa']
# ['49', '5.3', '3.7', '1.5', '0.2', 'Iris-setosa']
# ['50', '5.0', '3.3', '1.4', '0.2', 'Iris-setosa']
# ['51', '7.0', '3.2', '4.7', '1.4', 'Iris-versicolor']
# ['52', '6.4', '3.2', '4.5', '1.5', 'Iris-versicolor']
# ['53', '6.9', '3.1', '4.9', '1.5', 'Iris-versicolor']
# ['54', '5.5', '2.3', '4.0', '1.3', 'Iris-versicolor']
# ['55', '6.5', '2.8', '4.6', '1.5', 'Iris-versicolor']
# ['56', '5.7', '2.8', '4.5', '1.3', 'Iris-versicolor']
# ['57', '6.3', '3.3', '4.7', '1.6', 'Iris-versicolor']
# ['58', '4.9', '2.4', '3.3', '1.0', 'Iris-versicolor']
# ['59', '6.6', '2.9', '4.6', '1.3', 'Iris-versicolor']
# ['60', '5.2', '2.7', '3.9', '1.4', 'Iris-versicolor']
# ['61', '5.0', '2.0', '3.5', '1.0', 'Iris-versicolor']
# ['62', '5.9', '3.0', '4.2', '1.5', 'Iris-versicolor']
# ['63', '6.0', '2.2', '4.0', '1.0', 'Iris-versicolor']
# ['64', '6.1', '2.9', '4.7', '1.4', 'Iris-versicolor']
# ['65', '5.6', '2.9', '3.6', '1.3', 'Iris-versicolor']
# ['66', '6.7', '3.1', '4.4', '1.4', 'Iris-versicolor']
# ['67', '5.6', '3.0', '4.5', '1.5', 'Iris-versicolor']
# ['68', '5.8', '2.7', '4.1', '1.0', 'Iris-versicolor']
# ['69', '6.2', '2.2', '4.5', '1.5', 'Iris-versicolor']
# ['70', '5.6', '2.5', '3.9', '1.1', 'Iris-versicolor']
# ['71', '5.9', '3.2', '4.8', '1.8', 'Iris-versicolor']
# ['72', '6.1', '2.8', '4.0', '1.3', 'Iris-versicolor']
# ['73', '6.3', '2.5', '4.9', '1.5', 'Iris-versicolor']
# ['74', '6.1', '2.8', '4.7', '1.2', 'Iris-versicolor']
# ['75', '6.4', '2.9', '4.3', '1.3', 'Iris-versicolor']
# ['76', '6.6', '3.0', '4.4', '1.4', 'Iris-versicolor']
# ['77', '6.8', '2.8', '4.8', '1.4', 'Iris-versicolor']
# ['78', '6.7', '3.0', '5.0', '1.7', 'Iris-versicolor']
# ['79', '6.0', '2.9', '4.5', '1.5', 'Iris-versicolor']
# ['80', '5.7', '2.6', '3.5', '1.0', 'Iris-versicolor']
# ['81', '5.5', '2.4', '3.8', '1.1', 'Iris-versicolor']
# ['82', '5.5', '2.4', '3.7', '1.0', 'Iris-versicolor']
# ['83', '5.8', '2.7', '3.9', '1.2', 'Iris-versicolor']
# ['84', '6.0', '2.7', '5.1', '1.6', 'Iris-versicolor']
# ['85', '5.4', '3.0', '4.5', '1.5', 'Iris-versicolor']
# ['86', '6.0', '3.4', '4.5', '1.6', 'Iris-versicolor']
# ['87', '6.7', '3.1', '4.7', '1.5', 'Iris-versicolor']
# ['88', '6.3', '2.3', '4.4', '1.3', 'Iris-versicolor']
# ['89', '5.6', '3.0', '4.1', '1.3', 'Iris-versicolor']
# ['90', '5.5', '2.5', '4.0', '1.3', 'Iris-versicolor']
# ['91', '5.5', '2.6', '4.4', '1.2', 'Iris-versicolor']
# ['92', '6.1', '3.0', '4.6', '1.4', 'Iris-versicolor']
# ['93', '5.8', '2.6', '4.0', '1.2', 'Iris-versicolor']
# ['94', '5.0', '2.3', '3.3', '1.0', 'Iris-versicolor']
# ['95', '5.6', '2.7', '4.2', '1.3', 'Iris-versicolor']
# ['96', '5.7', '3.0', '4.2', '1.2', 'Iris-versicolor']
# ['97', '5.7', '2.9', '4.2', '1.3', 'Iris-versicolor']
# ['98', '6.2', '2.9', '4.3', '1.3', 'Iris-versicolor']
# ['99', '5.1', '2.5', '3.0', '1.1', 'Iris-versicolor']
# ['100', '5.7', '2.8', '4.1', '1.3', 'Iris-versicolor']
# ['101', '6.3', '3.3', '6.0', '2.5', 'Iris-virginica']
# ['102', '5.8', '2.7', '5.1', '1.9', 'Iris-virginica']
# ['103', '7.1', '3.0', '5.9', '2.1', 'Iris-virginica']
# ['104', '6.3', '2.9', '5.6', '1.8', 'Iris-virginica']
# ['105', '6.5', '3.0', '5.8', '2.2', 'Iris-virginica']
# ['106', '7.6', '3.0', '6.6', '2.1', 'Iris-virginica']
# ['107', '4.9', '2.5', '4.5', '1.7', 'Iris-virginica']
# ['108', '7.3', '2.9', '6.3', '1.8', 'Iris-virginica']
# ['109', '6.7', '2.5', '5.8', '1.8', 'Iris-virginica']
# ['110', '7.2', '3.6', '6.1', '2.5', 'Iris-virginica']
# ['111', '6.5', '3.2', '5.1', '2.0', 'Iris-virginica']
# ['112', '6.4', '2.7', '5.3', '1.9', 'Iris-virginica']
# ['113', '6.8', '3.0', '5.5', '2.1', 'Iris-virginica']
# ['114', '5.7', '2.5', '5.0', '2.0', 'Iris-virginica']
# ['115', '5.8', '2.8', '5.1', '2.4', 'Iris-virginica']
# ['116', '6.4', '3.2', '5.3', '2.3', 'Iris-virginica']
# ['117', '6.5', '3.0', '5.5', '1.8', 'Iris-virginica']
# ['118', '7.7', '3.8', '6.7', '2.2', 'Iris-virginica']
# ['119', '7.7', '2.6', '6.9', '2.3', 'Iris-virginica']
# ['120', '6.0', '2.2', '5.0', '1.5', 'Iris-virginica']
# ['121', '6.9', '3.2', '5.7', '2.3', 'Iris-virginica']
# ['122', '5.6', '2.8', '4.9', '2.0', 'Iris-virginica']
# ['123', '7.7', '2.8', '6.7', '2.0', 'Iris-virginica']
# ['124', '6.3', '2.7', '4.9', '1.8', 'Iris-virginica']
# ['125', '6.7', '3.3', '5.7', '2.1', 'Iris-virginica']
# ['126', '7.2', '3.2', '6.0', '1.8', 'Iris-virginica']
# ['127', '6.2', '2.8', '4.8', '1.8', 'Iris-virginica']
# ['128', '6.1', '3.0', '4.9', '1.8', 'Iris-virginica']
# ['129', '6.4', '2.8', '5.6', '2.1', 'Iris-virginica']
# ['130', '7.2', '3.0', '5.8', '1.6', 'Iris-virginica']
# ['131', '7.4', '2.8', '6.1', '1.9', 'Iris-virginica']
# ['132', '7.9', '3.8', '6.4', '2.0', 'Iris-virginica']
# ['133', '6.4', '2.8', '5.6', '2.2', 'Iris-virginica']
# ['134', '6.3', '2.8', '5.1', '1.5', 'Iris-virginica']
# ['135', '6.1', '2.6', '5.6', '1.4', 'Iris-virginica']
# ['136', '7.7', '3.0', '6.1', '2.3', 'Iris-virginica']
# ['137', '6.3', '3.4', '5.6', '2.4', 'Iris-virginica']
# ['138', '6.4', '3.1', '5.5', '1.8', 'Iris-virginica']
# ['139', '6.0', '3.0', '4.8', '1.8', 'Iris-virginica']
# ['140', '6.9', '3.1', '5.4', '2.1', 'Iris-virginica']
# ['141', '6.7', '3.1', '5.6', '2.4', 'Iris-virginica']
# ['142', '6.9', '3.1', '5.1', '2.3', 'Iris-virginica']
# ['143', '5.8', '2.7', '5.1', '1.9', 'Iris-virginica']
# ['144', '6.8', '3.2', '5.9', '2.3', 'Iris-virginica']
# ['145', '6.7', '3.3', '5.7', '2.5', 'Iris-virginica']
# ['146', '6.7', '3.0', '5.2', '2.3', 'Iris-virginica']
# ['147', '6.3', '2.5', '5.0', '1.9', 'Iris-virginica']
# ['148', '6.5', '3.0', '5.2', '2.0', 'Iris-virginica']
# ['149', '6.2', '3.4', '5.4', '2.3', 'Iris-virginica']
# ['150', '5.9', '3.0', '5.1', '1.8', 'Iris-virginica']

# %% [markdown]
# ### [Step 2] 여러개의 자료형 변환하기
# - 제목을 따로 저장하고, 실제 데이터만을 이용해 result 리스트에 저장하기
# - result에 저장된 값 중 꽃받침과 꽃잎의 길이, 너비값(1~4)을 실수형으로 변환하기
#   - 숫자형으로 변환해야 함 : 정수형(int), 실수형(float)

# %%
# csv 파일 데이터 불러오기 위한 모듈 선언
import csv


# Iris.csv 파일 열기
f= open('Iris.csv')

# Iris.csv 파일속 데이터를 data에 저장하기 
data = csv.reader(f)

## (실습) 제목을 따로 저장하기 위한 명령 : next(data) - 다음 행 
header = next(data)
print(header, type(header))

# 전체 데이터를 행별로 result 리스트에 저장 및 출력하기 
# 빈 리스트 result 만들기
result = []

# 전체 데이터를 행별로 result 리스트에 저장 및 출력하기 
for row in data :
    result.append(row)   # 행별로 데이터 저장하기
    print(row)           # 행별로 데이터 출력하기 

# (실습) result에 저장된 값 중 꽃받침과 꽃잎의 길이, 너비값(1~4)을 실수로 변환한 후 출력하기 
# 행(i), 열(j)
for row in result:
    for j in row[1:4]:
        print(float(j))
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species'] <class 'list'>
# ['1', '5.1', '3.5', '1.4', '0.2', 'Iris-setosa']
# ['2', '4.9', '3.0', '1.4', '0.2', 'Iris-setosa']
# ['3', '4.7', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['4', '4.6', '3.1', '1.5', '0.2', 'Iris-setosa']
# ['5', '5.0', '3.6', '1.4', '0.2', 'Iris-setosa']
# ['6', '5.4', '3.9', '1.7', '0.4', 'Iris-setosa']
# ['7', '4.6', '3.4', '1.4', '0.3', 'Iris-setosa']
# ['8', '5.0', '3.4', '1.5', '0.2', 'Iris-setosa']
# ['9', '4.4', '2.9', '1.4', '0.2', 'Iris-setosa']
# ['10', '4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['11', '5.4', '3.7', '1.5', '0.2', 'Iris-setosa']
# ['12', '4.8', '3.4', '1.6', '0.2', 'Iris-setosa']
# ['13', '4.8', '3.0', '1.4', '0.1', 'Iris-setosa']
# ['14', '4.3', '3.0', '1.1', '0.1', 'Iris-setosa']
# ['15', '5.8', '4.0', '1.2', '0.2', 'Iris-setosa']
# ['16', '5.7', '4.4', '1.5', '0.4', 'Iris-setosa']
# ['17', '5.4', '3.9', '1.3', '0.4', 'Iris-setosa']
# ['18', '5.1', '3.5', '1.4', '0.3', 'Iris-setosa']
# ['19', '5.7', '3.8', '1.7', '0.3', 'Iris-setosa']
# ['20', '5.1', '3.8', '1.5', '0.3', 'Iris-setosa']
# ['21', '5.4', '3.4', '1.7', '0.2', 'Iris-setosa']
# ['22', '5.1', '3.7', '1.5', '0.4', 'Iris-setosa']
# ['23', '4.6', '3.6', '1.0', '0.2', 'Iris-setosa']
# ['24', '5.1', '3.3', '1.7', '0.5', 'Iris-setosa']
# ['25', '4.8', '3.4', '1.9', '0.2', 'Iris-setosa']
# ['26', '5.0', '3.0', '1.6', '0.2', 'Iris-setosa']
# ['27', '5.0', '3.4', '1.6', '0.4', 'Iris-setosa']
# ['28', '5.2', '3.5', '1.5', '0.2', 'Iris-setosa']
# ['29', '5.2', '3.4', '1.4', '0.2', 'Iris-setosa']
# ['30', '4.7', '3.2', '1.6', '0.2', 'Iris-setosa']
# ['31', '4.8', '3.1', '1.6', '0.2', 'Iris-setosa']
# ['32', '5.4', '3.4', '1.5', '0.4', 'Iris-setosa']
# ['33', '5.2', '4.1', '1.5', '0.1', 'Iris-setosa']
# ['34', '5.5', '4.2', '1.4', '0.2', 'Iris-setosa']
# ['35', '4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['36', '5.0', '3.2', '1.2', '0.2', 'Iris-setosa']
# ['37', '5.5', '3.5', '1.3', '0.2', 'Iris-setosa']
# ['38', '4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['39', '4.4', '3.0', '1.3', '0.2', 'Iris-setosa']
# ['40', '5.1', '3.4', '1.5', '0.2', 'Iris-setosa']
# ['41', '5.0', '3.5', '1.3', '0.3', 'Iris-setosa']
# ['42', '4.5', '2.3', '1.3', '0.3', 'Iris-setosa']
# ['43', '4.4', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['44', '5.0', '3.5', '1.6', '0.6', 'Iris-setosa']
# ['45', '5.1', '3.8', '1.9', '0.4', 'Iris-setosa']
# ['46', '4.8', '3.0', '1.4', '0.3', 'Iris-setosa']
# ['47', '5.1', '3.8', '1.6', '0.2', 'Iris-setosa']
# ['48', '4.6', '3.2', '1.4', '0.2', 'Iris-setosa']
# ['49', '5.3', '3.7', '1.5', '0.2', 'Iris-setosa']
# ['50', '5.0', '3.3', '1.4', '0.2', 'Iris-setosa']
# ['51', '7.0', '3.2', '4.7', '1.4', 'Iris-versicolor']
# ['52', '6.4', '3.2', '4.5', '1.5', 'Iris-versicolor']
# ['53', '6.9', '3.1', '4.9', '1.5', 'Iris-versicolor']
# ['54', '5.5', '2.3', '4.0', '1.3', 'Iris-versicolor']
# ['55', '6.5', '2.8', '4.6', '1.5', 'Iris-versicolor']
# ['56', '5.7', '2.8', '4.5', '1.3', 'Iris-versicolor']
# ['57', '6.3', '3.3', '4.7', '1.6', 'Iris-versicolor']
# ['58', '4.9', '2.4', '3.3', '1.0', 'Iris-versicolor']
# ['59', '6.6', '2.9', '4.6', '1.3', 'Iris-versicolor']
# ['60', '5.2', '2.7', '3.9', '1.4', 'Iris-versicolor']
# ['61', '5.0', '2.0', '3.5', '1.0', 'Iris-versicolor']
# ['62', '5.9', '3.0', '4.2', '1.5', 'Iris-versicolor']
# ['63', '6.0', '2.2', '4.0', '1.0', 'Iris-versicolor']
# ['64', '6.1', '2.9', '4.7', '1.4', 'Iris-versicolor']
# ['65', '5.6', '2.9', '3.6', '1.3', 'Iris-versicolor']
# ['66', '6.7', '3.1', '4.4', '1.4', 'Iris-versicolor']
# ['67', '5.6', '3.0', '4.5', '1.5', 'Iris-versicolor']
# ['68', '5.8', '2.7', '4.1', '1.0', 'Iris-versicolor']
# ['69', '6.2', '2.2', '4.5', '1.5', 'Iris-versicolor']
# ['70', '5.6', '2.5', '3.9', '1.1', 'Iris-versicolor']
# ['71', '5.9', '3.2', '4.8', '1.8', 'Iris-versicolor']
# ['72', '6.1', '2.8', '4.0', '1.3', 'Iris-versicolor']
# ['73', '6.3', '2.5', '4.9', '1.5', 'Iris-versicolor']
# ['74', '6.1', '2.8', '4.7', '1.2', 'Iris-versicolor']
# ['75', '6.4', '2.9', '4.3', '1.3', 'Iris-versicolor']
# ['76', '6.6', '3.0', '4.4', '1.4', 'Iris-versicolor']
# ['77', '6.8', '2.8', '4.8', '1.4', 'Iris-versicolor']
# ['78', '6.7', '3.0', '5.0', '1.7', 'Iris-versicolor']
# ['79', '6.0', '2.9', '4.5', '1.5', 'Iris-versicolor']
# ['80', '5.7', '2.6', '3.5', '1.0', 'Iris-versicolor']
# ['81', '5.5', '2.4', '3.8', '1.1', 'Iris-versicolor']
# ['82', '5.5', '2.4', '3.7', '1.0', 'Iris-versicolor']
# ['83', '5.8', '2.7', '3.9', '1.2', 'Iris-versicolor']
# ['84', '6.0', '2.7', '5.1', '1.6', 'Iris-versicolor']
# ['85', '5.4', '3.0', '4.5', '1.5', 'Iris-versicolor']
# ['86', '6.0', '3.4', '4.5', '1.6', 'Iris-versicolor']
# ['87', '6.7', '3.1', '4.7', '1.5', 'Iris-versicolor']
# ['88', '6.3', '2.3', '4.4', '1.3', 'Iris-versicolor']
# ['89', '5.6', '3.0', '4.1', '1.3', 'Iris-versicolor']
# ['90', '5.5', '2.5', '4.0', '1.3', 'Iris-versicolor']
# ['91', '5.5', '2.6', '4.4', '1.2', 'Iris-versicolor']
# ['92', '6.1', '3.0', '4.6', '1.4', 'Iris-versicolor']
# ['93', '5.8', '2.6', '4.0', '1.2', 'Iris-versicolor']
# ['94', '5.0', '2.3', '3.3', '1.0', 'Iris-versicolor']
# ['95', '5.6', '2.7', '4.2', '1.3', 'Iris-versicolor']
# ['96', '5.7', '3.0', '4.2', '1.2', 'Iris-versicolor']
# ['97', '5.7', '2.9', '4.2', '1.3', 'Iris-versicolor']
# ['98', '6.2', '2.9', '4.3', '1.3', 'Iris-versicolor']
# ['99', '5.1', '2.5', '3.0', '1.1', 'Iris-versicolor']
# ['100', '5.7', '2.8', '4.1', '1.3', 'Iris-versicolor']
# ['101', '6.3', '3.3', '6.0', '2.5', 'Iris-virginica']
# ['102', '5.8', '2.7', '5.1', '1.9', 'Iris-virginica']
# ['103', '7.1', '3.0', '5.9', '2.1', 'Iris-virginica']
# ['104', '6.3', '2.9', '5.6', '1.8', 'Iris-virginica']
# ['105', '6.5', '3.0', '5.8', '2.2', 'Iris-virginica']
# ['106', '7.6', '3.0', '6.6', '2.1', 'Iris-virginica']
# ['107', '4.9', '2.5', '4.5', '1.7', 'Iris-virginica']
# ['108', '7.3', '2.9', '6.3', '1.8', 'Iris-virginica']
# ['109', '6.7', '2.5', '5.8', '1.8', 'Iris-virginica']
# ['110', '7.2', '3.6', '6.1', '2.5', 'Iris-virginica']
# ['111', '6.5', '3.2', '5.1', '2.0', 'Iris-virginica']
# ['112', '6.4', '2.7', '5.3', '1.9', 'Iris-virginica']
# ['113', '6.8', '3.0', '5.5', '2.1', 'Iris-virginica']
# ['114', '5.7', '2.5', '5.0', '2.0', 'Iris-virginica']
# ['115', '5.8', '2.8', '5.1', '2.4', 'Iris-virginica']
# ['116', '6.4', '3.2', '5.3', '2.3', 'Iris-virginica']
# ['117', '6.5', '3.0', '5.5', '1.8', 'Iris-virginica']
# ['118', '7.7', '3.8', '6.7', '2.2', 'Iris-virginica']
# ['119', '7.7', '2.6', '6.9', '2.3', 'Iris-virginica']
# ['120', '6.0', '2.2', '5.0', '1.5', 'Iris-virginica']
# ['121', '6.9', '3.2', '5.7', '2.3', 'Iris-virginica']
# ['122', '5.6', '2.8', '4.9', '2.0', 'Iris-virginica']
# ['123', '7.7', '2.8', '6.7', '2.0', 'Iris-virginica']
# ['124', '6.3', '2.7', '4.9', '1.8', 'Iris-virginica']
# ['125', '6.7', '3.3', '5.7', '2.1', 'Iris-virginica']
# ['126', '7.2', '3.2', '6.0', '1.8', 'Iris-virginica']
# ['127', '6.2', '2.8', '4.8', '1.8', 'Iris-virginica']
# ['128', '6.1', '3.0', '4.9', '1.8', 'Iris-virginica']
# ['129', '6.4', '2.8', '5.6', '2.1', 'Iris-virginica']
# ['130', '7.2', '3.0', '5.8', '1.6', 'Iris-virginica']
# ['131', '7.4', '2.8', '6.1', '1.9', 'Iris-virginica']
# ['132', '7.9', '3.8', '6.4', '2.0', 'Iris-virginica']
# ['133', '6.4', '2.8', '5.6', '2.2', 'Iris-virginica']
# ['134', '6.3', '2.8', '5.1', '1.5', 'Iris-virginica']
# ['135', '6.1', '2.6', '5.6', '1.4', 'Iris-virginica']
# ['136', '7.7', '3.0', '6.1', '2.3', 'Iris-virginica']
# ['137', '6.3', '3.4', '5.6', '2.4', 'Iris-virginica']
# ['138', '6.4', '3.1', '5.5', '1.8', 'Iris-virginica']
# ['139', '6.0', '3.0', '4.8', '1.8', 'Iris-virginica']
# ['140', '6.9', '3.1', '5.4', '2.1', 'Iris-virginica']
# ['141', '6.7', '3.1', '5.6', '2.4', 'Iris-virginica']
# ['142', '6.9', '3.1', '5.1', '2.3', 'Iris-virginica']
# ['143', '5.8', '2.7', '5.1', '1.9', 'Iris-virginica']
# ['144', '6.8', '3.2', '5.9', '2.3', 'Iris-virginica']
# ['145', '6.7', '3.3', '5.7', '2.5', 'Iris-virginica']
# ['146', '6.7', '3.0', '5.2', '2.3', 'Iris-virginica']
# ['147', '6.3', '2.5', '5.0', '1.9', 'Iris-virginica']
# ['148', '6.5', '3.0', '5.2', '2.0', 'Iris-virginica']
# ['149', '6.2', '3.4', '5.4', '2.3', 'Iris-virginica']
# ['150', '5.9', '3.0', '5.1', '1.8', 'Iris-virginica']
# 5.1
# 3.5
# 1.4
# 4.9
# 3.0
# 1.4
# 4.7
# 3.2
# 1.3
# 4.6
# 3.1
# 1.5
# 5.0
# 3.6
# 1.4
# 5.4
# 3.9
# 1.7
# 4.6
# 3.4
# 1.4
# 5.0
# 3.4
# 1.5
# 4.4
# 2.9
# 1.4
# 4.9
# 3.1
# 1.5
# 5.4
# 3.7
# 1.5
# 4.8
# 3.4
# 1.6
# 4.8
# 3.0
# 1.4
# 4.3
# 3.0
# 1.1
# 5.8
# 4.0
# 1.2
# 5.7
# 4.4
# 1.5
# 5.4
# 3.9
# 1.3
# 5.1
# 3.5
# 1.4
# 5.7
# 3.8
# 1.7
# 5.1
# 3.8
# 1.5
# 5.4
# 3.4
# 1.7
# 5.1
# 3.7
# 1.5
# 4.6
# 3.6
# 1.0
# 5.1
# 3.3
# 1.7
# 4.8
# 3.4
# 1.9
# 5.0
# 3.0
# 1.6
# 5.0
# 3.4
# 1.6
# 5.2
# 3.5
# 1.5
# 5.2
# 3.4
# 1.4
# 4.7
# 3.2
# 1.6
# 4.8
# 3.1
# 1.6
# 5.4
# 3.4
# 1.5
# 5.2
# 4.1
# 1.5
# 5.5
# 4.2
# 1.4
# 4.9
# 3.1
# 1.5
# 5.0
# 3.2
# 1.2
# 5.5
# 3.5
# 1.3
# 4.9
# 3.1
# 1.5
# 4.4
# 3.0
# 1.3
# 5.1
# 3.4
# 1.5
# 5.0
# 3.5
# 1.3
# 4.5
# 2.3
# 1.3
# 4.4
# 3.2
# 1.3
# 5.0
# 3.5
# 1.6
# 5.1
# 3.8
# 1.9
# 4.8
# 3.0
# 1.4
# 5.1
# 3.8
# 1.6
# 4.6
# 3.2
# 1.4
# 5.3
# 3.7
# 1.5
# 5.0
# 3.3
# 1.4
# 7.0
# 3.2
# 4.7
# 6.4
# 3.2
# 4.5
# 6.9
# 3.1
# 4.9
# 5.5
# 2.3
# 4.0
# 6.5
# 2.8
# 4.6
# 5.7
# 2.8
# 4.5
# 6.3
# 3.3
# 4.7
# 4.9
# 2.4
# 3.3
# 6.6
# 2.9
# 4.6
# 5.2
# 2.7
# 3.9
# 5.0
# 2.0
# 3.5
# 5.9
# 3.0
# 4.2
# 6.0
# 2.2
# 4.0
# 6.1
# 2.9
# 4.7
# 5.6
# 2.9
# 3.6
# 6.7
# 3.1
# 4.4
# 5.6
# 3.0
# 4.5
# 5.8
# 2.7
# 4.1
# 6.2
# 2.2
# 4.5
# 5.6
# 2.5
# 3.9
# 5.9
# 3.2
# 4.8
# 6.1
# 2.8
# 4.0
# 6.3
# 2.5
# 4.9
# 6.1
# 2.8
# 4.7
# 6.4
# 2.9
# 4.3
# 6.6
# 3.0
# 4.4
# 6.8
# 2.8
# 4.8
# 6.7
# 3.0
# 5.0
# 6.0
# 2.9
# 4.5
# 5.7
# 2.6
# 3.5
# 5.5
# 2.4
# 3.8
# 5.5
# 2.4
# 3.7
# 5.8
# 2.7
# 3.9
# 6.0
# 2.7
# 5.1
# 5.4
# 3.0
# 4.5
# 6.0
# 3.4
# 4.5
# 6.7
# 3.1
# 4.7
# 6.3
# 2.3
# 4.4
# 5.6
# 3.0
# 4.1
# 5.5
# 2.5
# 4.0
# 5.5
# 2.6
# 4.4
# 6.1
# 3.0
# 4.6
# 5.8
# 2.6
# 4.0
# 5.0
# 2.3
# 3.3
# 5.6
# 2.7
# 4.2
# 5.7
# 3.0
# 4.2
# 5.7
# 2.9
# 4.2
# 6.2
# 2.9
# 4.3
# 5.1
# 2.5
# 3.0
# 5.7
# 2.8
# 4.1
# 6.3
# 3.3
# 6.0
# 5.8
# 2.7
# 5.1
# 7.1
# 3.0
# 5.9
# 6.3
# 2.9
# 5.6
# 6.5
# 3.0
# 5.8
# 7.6
# 3.0
# 6.6
# 4.9
# 2.5
# 4.5
# 7.3
# 2.9
# 6.3
# 6.7
# 2.5
# 5.8
# 7.2
# 3.6
# 6.1
# 6.5
# 3.2
# 5.1
# 6.4
# 2.7
# 5.3
# 6.8
# 3.0
# 5.5
# 5.7
# 2.5
# 5.0
# 5.8
# 2.8
# 5.1
# 6.4
# 3.2
# 5.3
# 6.5
# 3.0
# 5.5
# 7.7
# 3.8
# 6.7
# 7.7
# 2.6
# 6.9
# 6.0
# 2.2
# 5.0
# 6.9
# 3.2
# 5.7
# 5.6
# 2.8
# 4.9
# 7.7
# 2.8
# 6.7
# 6.3
# 2.7
# 4.9
# 6.7
# 3.3
# 5.7
# 7.2
# 3.2
# 6.0
# 6.2
# 2.8
# 4.8
# 6.1
# 3.0
# 4.9
# 6.4
# 2.8
# 5.6
# 7.2
# 3.0
# 5.8
# 7.4
# 2.8
# 6.1
# 7.9
# 3.8
# 6.4
# 6.4
# 2.8
# 5.6
# 6.3
# 2.8
# 5.1
# 6.1
# 2.6
# 5.6
# 7.7
# 3.0
# 6.1
# 6.3
# 3.4
# 5.6
# 6.4
# 3.1
# 5.5
# 6.0
# 3.0
# 4.8
# 6.9
# 3.1
# 5.4
# 6.7
# 3.1
# 5.6
# 6.9
# 3.1
# 5.1
# 5.8
# 2.7
# 5.1
# 6.8
# 3.2
# 5.9
# 6.7
# 3.3
# 5.7
# 6.7
# 3.0
# 5.2
# 6.3
# 2.5
# 5.0
# 6.5
# 3.0
# 5.2
# 6.2
# 3.4
# 5.4
# 5.9
# 3.0
# 5.1

# %% [markdown]
# ## 03 데이터 다루기

# %% [markdown]
# ###[Step 1] 붓꽃 데이터를 종류별로 따로 저장하기
# - ['Id', SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, 'Species'] 에서 5번 인덱스에 있는 꽃을 종류별로 구분해 저장하기

# %%
# 꽃 종류별 데이터 저장하기 
a = []   # Iris-setosa 정보를 저장할 리스트 만들기 
b = []   # Iris-versicolor 정보를 저장할 리스트 만들기
c = []   # Iris-virginica 정보를 저장할 리스트 만들기 

# (실습) 각 행별로 5번 인덱스에 있는 꽃을 종류별로 구분해 데이터 저장하기 (인덱스 : 0~4) 

for i in result:
    if i[5] == 'Iris-setosa':
        a.append(i[:4])
    elif i[5] == 'Iris-versicolor':
        b.append(i[:4])
    elif i[5] == 'Iris-virginica':
        c.append(i[:4])

print(a)
print(b)
print(c)
# Out:
# [['1', '5.1', '3.5', '1.4'], ['2', '4.9', '3.0', '1.4'], ['3', '4.7', '3.2', '1.3'], ['4', '4.6', '3.1', '1.5'], ['5', '5.0', '3.6', '1.4'], ['6', '5.4', '3.9', '1.7'], ['7', '4.6', '3.4', '1.4'], ['8', '5.0', '3.4', '1.5'], ['9', '4.4', '2.9', '1.4'], ['10', '4.9', '3.1', '1.5'], ['11', '5.4', '3.7', '1.5'], ['12', '4.8', '3.4', '1.6'], ['13', '4.8', '3.0', '1.4'], ['14', '4.3', '3.0', '1.1'], ['15', '5.8', '4.0', '1.2'], ['16', '5.7', '4.4', '1.5'], ['17', '5.4', '3.9', '1.3'], ['18', '5.1', '3.5', '1.4'], ['19', '5.7', '3.8', '1.7'], ['20', '5.1', '3.8', '1.5'], ['21', '5.4', '3.4', '1.7'], ['22', '5.1', '3.7', '1.5'], ['23', '4.6', '3.6', '1.0'], ['24', '5.1', '3.3', '1.7'], ['25', '4.8', '3.4', '1.9'], ['26', '5.0', '3.0', '1.6'], ['27', '5.0', '3.4', '1.6'], ['28', '5.2', '3.5', '1.5'], ['29', '5.2', '3.4', '1.4'], ['30', '4.7', '3.2', '1.6'], ['31', '4.8', '3.1', '1.6'], ['32', '5.4', '3.4', '1.5'], ['33', '5.2', '4.1', '1.5'], ['34', '5.5', '4.2', '1.4'], ['35', '4.9', '3.1', '1.5'], ['36', '5.0', '3.2', '1.2'], ['37', '5.5', '3.5', '1.3'], ['38', '4.9', '3.1', '1.5'], ['39', '4.4', '3.0', '1.3'], ['40', '5.1', '3.4', '1.5'], ['41', '5.0', '3.5', '1.3'], ['42', '4.5', '2.3', '1.3'], ['43', '4.4', '3.2', '1.3'], ['44', '5.0', '3.5', '1.6'], ['45', '5.1', '3.8', '1.9'], ['46', '4.8', '3.0', '1.4'], ['47', '5.1', '3.8', '1.6'], ['48', '4.6', '3.2', '1.4'], ['49', '5.3', '3.7', '1.5'], ['50', '5.0', '3.3', '1.4']]
# [['51', '7.0', '3.2', '4.7'], ['52', '6.4', '3.2', '4.5'], ['53', '6.9', '3.1', '4.9'], ['54', '5.5', '2.3', '4.0'], ['55', '6.5', '2.8', '4.6'], ['56', '5.7', '2.8', '4.5'], ['57', '6.3', '3.3', '4.7'], ['58', '4.9', '2.4', '3.3'], ['59', '6.6', '2.9', '4.6'], ['60', '5.2', '2.7', '3.9'], ['61', '5.0', '2.0', '3.5'], ['62', '5.9', '3.0', '4.2'], ['63', '6.0', '2.2', '4.0'], ['64', '6.1', '2.9', '4.7'], ['65', '5.6', '2.9', '3.6'], ['66', '6.7', '3.1', '4.4'], ['67', '5.6', '3.0', '4.5'], ['68', '5.8', '2.7', '4.1'], ['69', '6.2', '2.2', '4.5'], ['70', '5.6', '2.5', '3.9'], ['71', '5.9', '3.2', '4.8'], ['72', '6.1', '2.8', '4.0'], ['73', '6.3', '2.5', '4.9'], ['74', '6.1', '2.8', '4.7'], ['75', '6.4', '2.9', '4.3'], ['76', '6.6', '3.0', '4.4'], ['77', '6.8', '2.8', '4.8'], ['78', '6.7', '3.0', '5.0'], ['79', '6.0', '2.9', '4.5'], ['80', '5.7', '2.6', '3.5'], ['81', '5.5', '2.4', '3.8'], ['82', '5.5', '2.4', '3.7'], ['83', '5.8', '2.7', '3.9'], ['84', '6.0', '2.7', '5.1'], ['85', '5.4', '3.0', '4.5'], ['86', '6.0', '3.4', '4.5'], ['87', '6.7', '3.1', '4.7'], ['88', '6.3', '2.3', '4.4'], ['89', '5.6', '3.0', '4.1'], ['90', '5.5', '2.5', '4.0'], ['91', '5.5', '2.6', '4.4'], ['92', '6.1', '3.0', '4.6'], ['93', '5.8', '2.6', '4.0'], ['94', '5.0', '2.3', '3.3'], ['95', '5.6', '2.7', '4.2'], ['96', '5.7', '3.0', '4.2'], ['97', '5.7', '2.9', '4.2'], ['98', '6.2', '2.9', '4.3'], ['99', '5.1', '2.5', '3.0'], ['100', '5.7', '2.8', '4.1']]
# [['101', '6.3', '3.3', '6.0'], ['102', '5.8', '2.7', '5.1'], ['103', '7.1', '3.0', '5.9'], ['104', '6.3', '2.9', '5.6'], ['105', '6.5', '3.0', '5.8'], ['106', '7.6', '3.0', '6.6'], ['107', '4.9', '2.5', '4.5'], ['108', '7.3', '2.9', '6.3'], ['109', '6.7', '2.5', '5.8'], ['110', '7.2', '3.6', '6.1'], ['111', '6.5', '3.2', '5.1'], ['112', '6.4', '2.7', '5.3'], ['113', '6.8', '3.0', '5.5'], ['114', '5.7', '2.5', '5.0'], ['115', '5.8', '2.8', '5.1'], ['116', '6.4', '3.2', '5.3'], ['117', '6.5', '3.0', '5.5'], ['118', '7.7', '3.8', '6.7'], ['119', '7.7', '2.6', '6.9'], ['120', '6.0', '2.2', '5.0'], ['121', '6.9', '3.2', '5.7'], ['122', '5.6', '2.8', '4.9'], ['123', '7.7', '2.8', '6.7'], ['124', '6.3', '2.7', '4.9'], ['125', '6.7', '3.3', '5.7'], ['126', '7.2', '3.2', '6.0'], ['127', '6.2', '2.8', '4.8'], ['128', '6.1', '3.0', '4.9'], ['129', '6.4', '2.8', '5.6'], ['130', '7.2', '3.0', '5.8'], ['131', '7.4', '2.8', '6.1'], ['132', '7.9', '3.8', '6.4'], ['133', '6.4', '2.8', '5.6'], ['134', '6.3', '2.8', '5.1'], ['135', '6.1', '2.6', '5.6'], ['136', '7.7', '3.0', '6.1'], ['137', '6.3', '3.4', '5.6'], ['138', '6.4', '3.1', '5.5'], ['139', '6.0', '3.0', '4.8'], ['140', '6.9', '3.1', '5.4'], ['141', '6.7', '3.1', '5.6'], ['142', '6.9', '3.1', '5.1'], ['143', '5.8', '2.7', '5.1'], ['144', '6.8', '3.2', '5.9'], ['145', '6.7', '3.3', '5.7'], ['146', '6.7', '3.0', '5.2'], ['147', '6.3', '2.5', '5.0'], ['148', '6.5', '3.0', '5.2'], ['149', '6.2', '3.4', '5.4'], ['150', '5.9', '3.0', '5.1']]

# %% [markdown]
# ### [Step 2] Iris-setosa의 꽃잎과 꽃받침 길이, 너비에 따른 평균 구하기
# - 붓꽃 특성
#   - 꽃받침 길이 : SepalLengthCm -> SL
#   - 꽃받침 너비 : SepalWidthCm -> SW
#   - 꽃잎 길이 : PetalLengthCm -> PL
#   - 꽃잎 너비 : PetalWidthCm -> PW
#
# - a 리스트 : Iris-setosa 정보 저장한 리스트
# - b 리스트 : Iris-versicolor 정보 저장할 리스트
# - c 리스트 : Iris-virginica 정보 저장할 리스트
#   - ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
SL = []   # 꽃받침 길이 : SepalLengthCm 리스트 만들기 
SW = []   # 꽃받침 너비 : SepalWidthCm 리스트 만들기
PL = []   # 꽃잎 길이 : PetalLengthCm 리스트 만들기 
PW = []   # 꽃잎 너비 : PetalWidthCm 리스트 만들기 

# (실습 )Iris-setosa의 전체 데이터 수만큼 반복하기
for i in a: 
    SL.append(float(i[0]))  # 꽃받침 길이 추가하기
    SW.append(float(i[1]))  # 꽃받침 너비 추가하기 
    PL.append(float(i[2]))  # 꽃잎 길이 추가하기
    PW.append(float(i[3]))  # 꽃잎 너비 추가하기 

# 제목 출력
print("< Iris-setosa의 특성별 평균 >")

# (실습) 평균 구해서 반올림해서 3자리까지 출력하기 
print("꽃받침 길이(SL) 평균 : ", round(sum(SL)/len(SL), 3))
print("꽃받침 너비(SW) 평균 : ", round(sum(SW)/len(SW), 3))
print("꽃잎 길이(PL) 평균 : ", round(sum(PL)/len(PL), 3))
print("꽃잎 너비(PW) 평균 : ", round(sum(PW)/len(PW), 3))
# Out:
# < Iris-setosa의 특성별 평균 >
# 꽃받침 길이(SL) 평균 :  25.5
# 꽃받침 너비(SW) 평균 :  5.006
# 꽃잎 길이(PL) 평균 :  3.418
# 꽃잎 너비(PW) 평균 :  1.464

# %% [markdown]
# ###[Step 3] Iris-setosa의 꽃잎과 꽃받침 길이, 너비의 중앙값 구하기
# - 중앙값 : 여러개의 값을 오름차순으로 정렬한 후, 중앙에 위치한 값을 찾기
#
# - len(리스트명) : 리스트 요소갯수
# - 리스트명.sort() : 리스트의 값을 오름차순으로 나열하는 내장함수
# - 붓꽃 특성
#   - 꽃받침 길이 : SepalLengthCm -> SL
#   - 꽃받침 너비 : SepalWidthCm -> SW
#   - 꽃잎 길이 : PetalLengthCm -> PL
#   - 꽃잎 너비 : PetalWidthCm -> PW

# %%
# (실습) Iris-setosa의 꽃받침 길이(SL), 꽃받침 너비(SW) 꽃잎 길이(PL), 꽃잎 너비(PW) 오름차순 구하기 
SL.sort()
SW.sort()
PL.sort()
PW.sort()

# (실습) Iris-setosa의 전체 개수를 2로 나누어 중앙에 해당되는 위치(인덱스, m) 구하기 
m = int(len(a) / 2)

# 제목 출력하기 
print("< Iris-setosa의 특성별 중앙값 >")

# 중앙값 구하기 
print("꽃받침 길이 중앙값 : " , SL[m])
print("꽃받침 너비 중앙값 : ", SW[m])
print("꽃잎 길이 중앙값 : ", PL[m])
print("꽃잎 너비 중앙값 : ", PW[m])
# Out:
# < Iris-setosa의 특성별 중앙값 >
# 꽃받침 길이 중앙값 :  26.0
# 꽃받침 너비 중앙값 :  5.0
# 꽃잎 길이 중앙값 :  3.4
# 꽃잎 너비 중앙값 :  1.5

# %% [markdown]
# ## 04 데이터 시각화하기

# %% [markdown]
# ###[Step 1] Iris.csv 파일에 있는 전체 데이터 요약하기
# - pandas 를 이용하여 데이터프레임(iris)을 만들어서
#   1. 처음 2개 행 데이터 출력하기
#   2. 데이터프레임 요약 출력하기
#   3. 데이터프레임 통계값 요약 출력하기  : 갯수, 평균, 표준편차, 최솟값, 최댓값 등등

# %%
import pandas as pd

# (실습)iris 데이터프레임 생성하기(Iris.csv)
iris_csv = pd.read_csv('iris.csv')
iris = pd.DataFrame(iris_csv)

# (실습) iris의 처음 2개 행의 데이터 출력하기
print(iris.head(2))

# (실습) iris 데이터프레임 요약한 것 출력하기
print(iris.head())

# (실습) iris 데이터프레임의 통계값 요약 출력하기 
# 갯수, 평균, 표준편차, 최솟값, 최댓값 등 출력 
print(iris.describe())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### [Step 2] 꽃받침 길이와 너비를 분산형 그래프로 나타내기
# - x축 : 꽃받침 길이(SepalLengthCm)
# - y축 : 꽃받침 너비(SepalWidthCm)
# - 그래프 종류 : 분산형(scatter)
# - 종류별 색깔(iris.Species)
#   -  'Iris-setosa' : 오렌지색('orange')
#   -  'Iris-versicolor' : 파란색('blue')
#   - 'Iris-virginica' : 녹색('green')
#
# #### pandas의 plot() 메소드
# - 시리즈나 데이터프레임에 plot() 이라는 시각화 메소드를 내장함
# - plot() : matplotlib을 내부에서 임포트하여 사용함
#
# #### matplotlib
# - fig(figure)
#   - 그림이 그려지나 캔버스나 종이
# - axis(축)
#   - 가로축이나 세로축 등의 축
# - ax(axes)
#   - figure 내에서 축(axis)을 가지는 하나의 좌표평면과 같은 개념, 실제로 데이터가 그려지는 곳

# %%
# (실습) iris 데이터프레임에서 아이리스 종류가 [iris.Species == 'Iris-setosa']인 값만 출력
print(iris[iris.Species == 'Iris-setosa'])
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 19  20            5.1           3.8            1.5           0.3  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# 22  23            4.6           3.6            1.0           0.2  Iris-setosa
# 23  24            5.1           3.3            1.7           0.5  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 25  26            5.0           3.0            1.6           0.2  Iris-setosa
# 26  27            5.0           3.4            1.6           0.4  Iris-setosa
# 27  28            5.2           3.5            1.5           0.2  Iris-setosa
# 28  29            5.2           3.4            1.4           0.2  Iris-setosa
# 29  30            4.7           3.2            1.6           0.2  Iris-setosa
# 30  31            4.8           3.1            1.6           0.2  Iris-setosa
# 31  32            5.4           3.4            1.5           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa
# 34  35            4.9           3.1            1.5           0.1  Iris-setosa
# 35  36            5.0           3.2            1.2           0.2  Iris-setosa
# 36  37            5.5           3.5            1.3           0.2  Iris-setosa
# 37  38            4.9           3.1            1.5           0.1  Iris-setosa
# 38  39            4.4           3.0            1.3           0.2  Iris-setosa
# 39  40            5.1           3.4            1.5           0.2  Iris-setosa
# 40  41            5.0           3.5            1.3           0.3  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa
# 42  43            4.4           3.2            1.3           0.2  Iris-setosa
# 43  44            5.0           3.5            1.6           0.6  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa
# 45  46            4.8           3.0            1.4           0.3  Iris-setosa
# 46  47            5.1           3.8            1.6           0.2  Iris-setosa
# 47  48            4.6           3.2            1.4           0.2  Iris-setosa
# 48  49            5.3           3.7            1.5           0.2  Iris-setosa
# 49  50            5.0           3.3            1.4           0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt

# 꽃받침 길이(SepalLength)와 너비(SepalWidth)에 따른 분산형(scatter) 그래프
# Iris의 종류(Species)에 따라 색깔별로 분산형 그래프 그리기 (ax = fig 같은 좌표평면에 fig 넣기)
# Iris-setosa('orange'), Iris-versicolor('blue'), Iris-virginica('green')
fig = iris[ iris.Species == 'Iris-setosa'].plot(kind='scatter',x = 'SepalLengthCm', y = 'SepalWidthCm', color='orange', label = 'setosa')
iris[ iris.Species == 'Iris-versicolor'].plot(kind='scatter',x = 'SepalLengthCm', y = 'SepalWidthCm', color='blue', label = 'versicolor')
iris[ iris.Species == 'Iris-virginica'].plot(kind='scatter',x = 'SepalLengthCm', y = 'SepalWidthCm', color='green', label = 'virginica')

fig.set_xlabel('Sepal Length')
fig.set_ylabel('Sepal Width')
fig.set_title('Sepal Length vs Width')

# plt.gcf() : Get the current figure (figure의 설정정보 확인 가능 )
# fig = plt.gcf()

# fig.set_size_inches(10, 6) : 그래프의 크기를 인치로 지정함 
# fig.set_size_inches(10, 6)
plt.show()

# %% [markdown]
# ### [Step 3] 꽃잎의 길이와 너비를 분산형 그래프로 나타내기

# %%
# 꽃잎(Petal)의 길이(PetalLengthCm)와 너비(PetalWidthCm)에 따른 분산형(scatter) 그래프
fig = iris[ iris.Species == 'Iris-setosa'].plot(kind = 'scatter', x = 'PetalLengthCm', y = 'PetalWidthCm', color = 'orange', label = 'setosa')
iris[iris.Species == 'Iris-versicolor'].plot(kind = 'scatter', x = 'PetalLengthCm', y = 'PetalWidthCm', color = 'blue', label = 'versicolor', ax = fig)
iris[iris.Species == 'Iris-virginica'].plot(kind = 'scatter', x = 'PetalLengthCm', y = 'PetalWidthCm', color = 'green', label = 'virginica', ax = fig)

# 제목, x, y 축 제목
fig.set_title('Petal Length vs Width')
fig.set_xlabel('Petal Length')
fig.set_ylabel('Petal Width')

# plt.gcf() : Get the current figure (figure의 설정정보 확인 가능)
fig = plt.gcf()
fig.set_size_inches(10, 6)
plt.show()

# %%
# result_ice.csv 를 두개파일을 병합해서 만든다.
import pandas as pd

temp = pd.read_csv('temp.csv')
ice = pd.read_csv('icecream.csv')

result_ice = pd.concat([temp, ice['아이스크림/빙수']], axis=1)
result_ice.to_csv('result_ice.csv')
result_ice
# Out:
#              날짜  지점  평균기온(℃)  최저기온(℃)  최고기온(℃)  아이스크림/빙수
# 0    2019-01-01  전국     -2.1     -5.8      2.1        26
# 1    2019-01-02  전국     -2.5     -7.0      3.2        27
# 2    2019-01-03  전국     -2.1     -7.7      5.0        25
# 3    2019-01-04  전국     -0.7     -7.3      5.3        24
# 4    2019-01-05  전국      0.2     -4.6      5.3        25
# ..          ...  ..      ...      ...      ...       ...
# 360  2019-12-27  전국      0.6     -3.2      5.1        24
# 361  2019-12-28  전국      0.5     -4.9      7.5        25
# 362  2019-12-29  전국      2.6     -2.4      6.6        31
# 363  2019-12-30  전국      5.0      0.1      9.8        29
# 364  2019-12-31  전국     -3.8     -6.7      0.4        22
#
# [365 rows x 6 columns]
